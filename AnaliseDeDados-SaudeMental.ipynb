# %% [markdown]
# # ANÁLISE DE DADOS SOBRE SAÚDE MENTAL
#
# Disclaimer/Aviso Legal: Este notebook tem um fim única e exclusivamente didático, para alunos da FATEC, como uma introdução à Análise de Dados Públicos. Desse modo, está excluída a garantia ou responsabilidade de qualquer tipo, por exemplo, de precisão, confiabilidade, completude e atualidade das informações.
#
# Feito por:
# - Larissa Miho
# - Ângelo Lima

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
data = pd.read_csv("data.csv")

# %%
for coluna in enumerate(data.columns): print (coluna)
# Out:
# (0, 'Timestamp')
# (1, 'Age')
# (2, 'Gender')
# (3, 'Country')
# (4, 'state')
# (5, 'self_employed')
# (6, 'family_history')
# (7, 'treatment')
# (8, 'work_interfere')
# (9, 'no_employees')
# (10, 'remote_work')
# (11, 'tech_company')
# (12, 'benefits')
# (13, 'care_options')
# (14, 'wellness_program')
# (15, 'seek_help')
# (16, 'anonymity')
# (17, 'leave')
# (18, 'mental_health_consequence')
# (19, 'phys_health_consequence')
# (20, 'coworkers')
# (21, 'supervisor')
# (22, 'mental_health_interview')
# (23, 'phys_health_interview')
# (24, 'mental_vs_physical')
# (25, 'obs_consequence')
# (26, 'comments')

# %%
data.rename(columns={'Age': 'IDADE',
                    'Gender': 'GENERO',
                    'family_history': 'HISTORICO_FAMILIAR',
                    'treatment': 'TEM_TRATAMENTO',
                    'work_interfere': 'INTERFERE_NO_TRABALHO',
                    'supervisor': 'SUPERVISAO_MEDICA'}, inplace = True)

# %%
data.sample(40)
# Out:
#                 Timestamp  IDADE  GENERO         Country state self_employed  \
# 156   2014-08-27 12:42:52     27    Male   United States    CA            No
# 312   2014-08-27 14:25:41     36    Male   United States    WA           Yes
# 921   2014-08-28 20:12:08     35    Male   United States    UT            No
# 167   2014-08-27 12:48:29     42    male   United States    CA            No
# 611   2014-08-27 23:56:33     42    Male   United States    WI           Yes
# 1089  2014-08-29 17:04:12     28  Female   United States    CA            No
# 945   2014-08-29 00:05:07     39    Male   United States    AZ            No
# 1140  2014-09-01 09:12:15     26    Male         Moldova   NaN            No
# 803   2014-08-28 13:41:51     30  Female   United States    CA            No
# 205   2014-08-27 13:02:14     32    Male  United Kingdom   NaN            No
# 845   2014-08-28 16:56:26     37    Male           Italy   NaN            No
# 1067  2014-08-29 12:27:54     26    Male   United States    PA            No
# 126   2014-08-27 12:34:13     27    Male  United Kingdom   NaN            No
# 295   2014-08-27 14:16:00     24  Female   United States    CA            No
# 658   2014-08-28 04:37:54     30       M  United Kingdom   NaN            No
# 575   2014-08-27 20:52:31     37    Male   United States    PA            No
# 1184  2014-10-09 11:14:59     28       F   United States    VA            No
# 834   2014-08-28 15:56:47     34    male   United States    TX            No
# 650   2014-08-28 04:07:34     39       M   United States    FL            No
# 113   2014-08-27 12:31:14     32    Male   United States    NY            No
# 820   2014-08-28 14:52:46     40  Female   United States    WA            No
# 1257  2015-11-30 21:25:06     46       f   United States    NC            No
# 139   2014-08-27 12:37:50     22       m         Austria   NaN            No
# 34    2014-08-27 11:40:51     40  female   United States    WI            No
# 929   2014-08-28 21:38:12     31    Male   United States    MO            No
# 633   2014-08-28 02:49:34     34  female   United States    CA            No
# 1048  2014-08-29 11:27:47     41    Male   United States    IL           Yes
# 21    2014-08-27 11:35:24     31    male   United States    NC           Yes
# 140   2014-08-27 12:38:11     38    Male   United States    OR            No
# 471   2014-08-27 16:13:40     58    Male   United States    CA            No
# 534   2014-08-27 17:47:45     21    Male          Canada   NaN            No
# 61    2014-08-27 11:49:51     26  Female          Poland   NaN            No
# 92    2014-08-27 12:14:13     34    Male   United States    OH            No
# 142   2014-08-27 12:38:25     35       M   United States    TX            No
# 445   2014-08-27 15:46:39     39    Male   United States    CA            No
# 1091  2014-08-29 17:32:31     43    male   United States    TX            No
# 705   2014-08-28 10:00:48     32    Male  United Kingdom   NaN            No
# 442   2014-08-27 15:44:16     41       m   United States    PA            No
# 1164  2014-09-04 23:42:28     46  Female   United States    CA            No
# 105   2014-08-27 12:23:48     35    Male   United States    MO            No
#
#      HISTORICO_FAMILIAR TEM_TRATAMENTO INTERFERE_NO_TRABALHO    no_employees  \
# 156                 Yes            Yes             Sometimes  More than 1000
# 312                  No            Yes                 Never             1-5
# 921                 Yes            Yes                Rarely          26-100
# 167                  No             No                   NaN            6-25
# 611                  No             No                Rarely            6-25
# 1089                Yes            Yes             Sometimes         100-500
# 945                 Yes            Yes                 Often          26-100
# 1140                 No            Yes                 Often          26-100
# 803                  No             No                   NaN  More than 1000
# 205                 Yes            Yes             Sometimes         100-500
# 845                  No             No             Sometimes          26-100
# 1067                 No             No                 Never  More than 1000
# 126                  No             No                   NaN            6-25
# 295                  No             No                   NaN        500-1000
# 658                 Yes            Yes             Sometimes  More than 1000
# 575                 Yes             No                 Never          26-100
# 1184                 No            Yes                 Often            6-25
# 834                  No            Yes             Sometimes             1-5
# 650                  No             No                Rarely  More than 1000
# 113                  No             No                 Never         100-500
# 820                 Yes            Yes             Sometimes         100-500
# 1257                 No             No                   NaN         100-500
# 139                  No             No                   NaN            6-25
# 34                   No            Yes             Sometimes             1-5
# 929                 Yes             No                 Never         100-500
# 633                  No            Yes             Sometimes         100-500
# 1048                 No            Yes                 Often             1-5
# 21                   No             No                 Never             1-5
# 140                 Yes            Yes             Sometimes         100-500
# 471                  No            Yes                Rarely  More than 1000
# 534                  No             No                 Never          26-100
# 61                   No            Yes             Sometimes          26-100
# 92                   No             No                   NaN          26-100
# 142                  No             No                 Never          26-100
# 445                 Yes             No                 Often  More than 1000
# 1091                Yes             No                 Never         100-500
# 705                  No            Yes                Rarely         100-500
# 442                  No            Yes             Sometimes  More than 1000
# 1164                 No            Yes                 Often         100-500
# 105                 Yes             No                Rarely            6-25
#
#       ...               leave mental_health_consequence  \
# 156   ...          Don't know                        No
# 312   ...       Somewhat easy                     Maybe
# 921   ...  Somewhat difficult                     Maybe
# 167   ...      Very difficult                     Maybe
# 611   ...           Very easy                        No
# 1089  ...          Don't know                     Maybe
# 945   ...          Don't know                       Yes
# 1140  ...      Very difficult                        No
# 803   ...           Very easy                        No
# 205   ...  Somewhat difficult                       Yes
# 845   ...          Don't know                       Yes
# 1067  ...  Somewhat difficult                     Maybe
# 126   ...          Don't know                        No
# 295   ...          Don't know                     Maybe
# 658   ...          Don't know                     Maybe
# 575   ...       Somewhat easy                        No
# 1184  ...      Very difficult                       Yes
# 834   ...          Don't know                       Yes
# 650   ...          Don't know                        No
# 113   ...          Don't know                     Maybe
# 820   ...          Don't know                       Yes
# 1257  ...          Don't know                       Yes
# 139   ...       Somewhat easy                        No
# 34    ...          Don't know                     Maybe
# 929   ...           Very easy                        No
# 633   ...       Somewhat easy                     Maybe
# 1048  ...      Very difficult                        No
# 21    ...  Somewhat difficult                        No
# 140   ...          Don't know                     Maybe
# 471   ...       Somewhat easy                     Maybe
# 534   ...          Don't know                       Yes
# 61    ...           Very easy                        No
# 92    ...       Somewhat easy                     Maybe
# 142   ...          Don't know                       Yes
# 445   ...          Don't know                       Yes
# 1091  ...       Somewhat easy                     Maybe
# 705   ...          Don't know                     Maybe
# 442   ...          Don't know                     Maybe
# 1164  ...          Don't know                     Maybe
# 105   ...       Somewhat easy                        No
#
#      phys_health_consequence     coworkers SUPERVISAO_MEDICA  \
# 156                       No            No      Some of them
# 312                       No  Some of them               Yes
# 921                       No  Some of them      Some of them
# 167                       No           Yes               Yes
# 611                       No  Some of them               Yes
# 1089                      No  Some of them      Some of them
# 945                       No  Some of them                No
# 1140                      No           Yes               Yes
# 803                       No  Some of them                No
# 205                    Maybe            No                No
# 845                      Yes  Some of them                No
# 1067                      No            No               Yes
# 126                       No  Some of them      Some of them
# 295                    Maybe  Some of them                No
# 658                       No  Some of them               Yes
# 575                       No           Yes               Yes
# 1184                   Maybe  Some of them      Some of them
# 834                       No            No                No
# 650                       No  Some of them      Some of them
# 113                       No  Some of them      Some of them
# 820                    Maybe  Some of them                No
# 1257                      No            No                No
# 139                       No  Some of them      Some of them
# 34                        No  Some of them                No
# 929                       No  Some of them               Yes
# 633                       No  Some of them               Yes
# 1048                      No  Some of them      Some of them
# 21                        No  Some of them      Some of them
# 140                       No  Some of them               Yes
# 471                       No  Some of them               Yes
# 534                    Maybe            No                No
# 61                        No           Yes               Yes
# 92                        No  Some of them                No
# 142                       No  Some of them                No
# 445                       No  Some of them      Some of them
# 1091                      No  Some of them      Some of them
# 705                       No           Yes               Yes
# 442                       No  Some of them               Yes
# 1164                      No  Some of them      Some of them
# 105                       No  Some of them               Yes
#
#      mental_health_interview phys_health_interview mental_vs_physical  \
# 156                       No                 Maybe         Don't know
# 312                       No                    No                Yes
# 921                       No                    No                 No
# 167                       No                 Maybe                 No
# 611                    Maybe                 Maybe                Yes
# 1089                      No                    No                Yes
# 945                       No                    No                 No
# 1140                     Yes                   Yes         Don't know
# 803                       No                    No                Yes
# 205                       No                    No                 No
# 845                       No                    No                 No
# 1067                      No                    No         Don't know
# 126                       No                    No         Don't know
# 295                       No                 Maybe                 No
# 658                       No                   Yes                Yes
# 575                       No                    No                Yes
# 1184                      No                    No         Don't know
# 834                       No                   Yes         Don't know
# 650                       No                 Maybe         Don't know
# 113                       No                    No         Don't know
# 820                       No                    No         Don't know
# 1257                      No                    No                 No
# 139                       No                    No         Don't know
# 34                        No                 Maybe                Yes
# 929                       No                    No         Don't know
# 633                       No                    No                Yes
# 1048                      No                    No                Yes
# 21                        No                 Maybe                Yes
# 140                       No                    No         Don't know
# 471                       No                   Yes                Yes
# 534                       No                 Maybe         Don't know
# 61                     Maybe                   Yes                Yes
# 92                        No                 Maybe         Don't know
# 142                       No                 Maybe         Don't know
# 445                       No                 Maybe                 No
# 1091                      No                 Maybe                 No
# 705                       No                 Maybe                 No
# 442                    Maybe                   Yes                Yes
# 1164                      No                 Maybe                 No
# 105                       No                    No         Don't know
#
#      obs_consequence                                           comments
# 156               No                                                NaN
# 312               No                                                NaN
# 921               No                                                NaN
# 167               No                                                NaN
# 611               No                                                NaN
# 1089              No                                                NaN
# 945               No                                                NaN
# 1140              No                                                NaN
# 803               No                                                NaN
# 205              Yes  I've answered 'Yes' on remote working but 50% ...
# 845               No                                                NaN
# 1067              No                                                NaN
# 126               No                                                NaN
# 295               No                                                NaN
# 658               No                                                NaN
# 575               No                                                NaN
# 1184              No                                                NaN
# 834               No                                                NaN
# 650               No  I mostly suffer from social anxiety which keep...
# 113               No                                                NaN
# 820               No                                                NaN
# 1257              No                                                NaN
# 139               No                                                NaN
# 34                No                                                NaN
# 929               No                                                NaN
# 633               No                                                NaN
# 1048             Yes                                                NaN
# 21                No                                                NaN
# 140               No                                                NaN
# 471               No                                                NaN
# 534               No                                                NaN
# 61                No                                                NaN
# 92                No                                                NaN
# 142               No                                                NaN
# 445              Yes                                                NaN
# 1091              No                                                NaN
# 705              Yes                                                NaN
# 442              Yes                                                NaN
# 1164              No                                                NaN
# 105               No                                                NaN
#
# [40 rows x 27 columns]

# %%
plt.title('Gráfico de Idades de Pessoas com Doenças Mentais')
plt.ylabel('Quantidade de Pessoas')

data.query('IDADE >= 0 and IDADE <= 120').groupby('IDADE').size().plot(kind='bar', figsize=(18,10),color='#A020F0',rot=40)

# %%
data.loc[(data.HISTORICO_FAMILIAR == 'Yes'), 'HISTORICO_FAMILIAR'] = 'Sim'
data.loc[(data.HISTORICO_FAMILIAR == 'No'), 'HISTORICO_FAMILIAR'] = 'Não'

# %%
plt.title('Se pessoas tem um histórico familiar com doenças mentais')

data.groupby('HISTORICO_FAMILIAR').size().plot(kind='bar', figsize=(5,5),  color='#A020F0',rot=40)

# %%
data.loc[(data.TEM_TRATAMENTO == 'Yes'), 'TEM_TRATAMENTO'] = 'Sim'
data.loc[(data.TEM_TRATAMENTO == 'No'), 'TEM_TRATAMENTO'] = 'Não'

# %%
plt.title('Pessoas com doenças mentais que tem tratamento')

data.groupby('TEM_TRATAMENTO').size().plot(kind='bar', figsize=(5,5),  color='#A020F0',rot=40)

# %%
data.loc[(data.INTERFERE_NO_TRABALHO == 'Often'), 'INTERFERE_NO_TRABALHO'] = 'Frequentemente'
data.loc[(data.INTERFERE_NO_TRABALHO == 'Rarely'), 'INTERFERE_NO_TRABALHO'] = 'Raramente'
data.loc[(data.INTERFERE_NO_TRABALHO == 'Never'), 'INTERFERE_NO_TRABALHO'] = 'Nunca'
data.loc[(data.INTERFERE_NO_TRABALHO == 'Sometimes'), 'INTERFERE_NO_TRABALHO'] = 'As Vezes'

# %%
plt.title('Pessoas que tem doenças mentais e que isso os atrapalham na hora do trabalho')

data.groupby('INTERFERE_NO_TRABALHO').size().plot(kind='barh', figsize=(5,5),  color='#A020F0',rot=40)

# %%
data.loc[(data.SUPERVISAO_MEDICA == 'Yes'), 'SUPERVISAO_MEDICA'] = 'Sim'
data.loc[(data.SUPERVISAO_MEDICA == 'No'), 'SUPERVISAO_MEDICA'] = 'Não'
data.loc[(data.SUPERVISAO_MEDICA == 'Some of them'), 'SUPERVISAO_MEDICA'] = 'Algumas vezes'

# %%
plt.title('Pessoas com acompanhamento médico')

data.groupby('SUPERVISAO_MEDICA').size().plot(kind='barh', figsize=(5,5),  color='#A020F0',rot=40)

# %%
data2 = data.copy()
data.loc[(data.GENERO == 'Male'), 'GENERO'] = 'Homens'
data.loc[(data.GENERO == 'male'), 'GENERO'] = 'Homens'
data.loc[(data.GENERO == 'M'), 'GENERO'] = 'Homens'
data.loc[(data.GENERO == 'Female'), 'GENERO'] = 'Mulheres'
data.loc[(data.GENERO == 'female'), 'GENERO'] = 'Mulheres'
data.loc[(data.GENERO == 'F'), 'GENERO'] = 'Mulheres'
data2.loc[(data.GENERO == 'Mulheres'), 'GENERO'] = 'Hetero'
data2.loc[(data.GENERO == 'Homens'), 'GENERO'] = 'Hetero'
data.loc[(data2.GENERO != 'Hetero'), 'GENERO'] = 'Outros'

# %%
plt.title('Gênero das pessoas com doenças mentais')

data.groupby('GENERO').size().plot(kind='bar', figsize=(5,5),  color='#A020F0',rot=40)
